# %%
# ml class 1

# %%
import numpy as np

# %%
a=np.random.randint(0,9,(5,5))
b=np.random.randint(0,9,(5,5))
c=np.ones((5,5),'int')

# %%
a
# Out:
# array([[3, 3, 0, 3, 0],
#        [6, 4, 6, 8, 5],
#        [4, 7, 8, 4, 4],
#        [6, 8, 4, 1, 8],
#        [8, 8, 3, 3, 6]])

# %%
b
# Out:
# array([[5, 0, 5, 1, 4],
#        [2, 3, 5, 6, 7],
#        [7, 3, 2, 3, 8],
#        [3, 5, 8, 5, 1],
#        [3, 2, 1, 2, 3]])

# %%
c=np.ones((5,5),'int')
for i in range(0,5):
    for j in range(0,5):
        for k in range(0,5):
            c[i][j] += a[i][k]*b[k][j]

# %%
c
# Out:
# array([[ 31,  25,  55,  37,  37],
#        [120,  81, 132,  99, 124],
#        [115,  74, 108,  99, 146],
#        [102,  58,  95,  88, 138],
#        [105,  61, 117,  93, 134]])

# %%
z=np.multiply(a,b)
z
# Out:
# array([[15,  0,  0,  3,  0],
#        [12, 12, 30, 48, 35],
#        [28, 21, 16, 12, 32],
#        [18, 40, 32,  5,  8],
#        [24, 16,  3,  6, 18]])

# %%
import statistics as st
# mean
m=np.mean(a)
m
# Out:
# 3.68

# %%
mod=np.median(a)
mod
# Out:
# 4.0

# %%
mo=st.mode(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9836\2826521710.py in <module>
# ----> 1 mo=st.mode(a)
#
# ~\anaconda3\lib\statistics.py in mode(data)
#     555
#     556     """
# --> 557     pairs = Counter(iter(data)).most_common(1)
#     558     try:
#     559         return pairs[0][0]
#
# ~\anaconda3\lib\collections\__init__.py in __init__(self, iterable, **kwds)
#     591         '''
#     592         super().__init__()
# --> 593         self.update(iterable, **kwds)
#     594
#     595     def __missing__(self, key):
#
# ~\anaconda3\lib\collections\__init__.py in update(self, iterable, **kwds)
#     677                     super().update(iterable)
#     678             else:
# --> 679                 _count_elements(self, iterable)
#     680         if kwds:
#     681             self.update(kwds)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
a
# Out:
# array([[8, 2, 7, 6, 6],
#        [4, 2, 5, 6, 3],
#        [0, 2, 4, 3, 0],
#        [0, 2, 1, 2, 1],
#        [0, 5, 2, 1, 1]])

# %%
a = a.reshape((1,-1))
a
# Out:
# array([[8, 2, 7, 6, 6, 4, 2, 5, 6, 3, 0, 2, 4, 3, 0, 0, 2, 1, 2, 1, 0, 5,
#         2, 1, 1]])

# %%
st.mode(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9836\1319879173.py in <module>
# ----> 1 st.mode(a)
#
# ~\anaconda3\lib\statistics.py in mode(data)
#     555
#     556     """
# --> 557     pairs = Counter(iter(data)).most_common(1)
#     558     try:
#     559         return pairs[0][0]
#
# ~\anaconda3\lib\collections\__init__.py in __init__(self, iterable, **kwds)
#     591         '''
#     592         super().__init__()
# --> 593         self.update(iterable, **kwds)
#     594
#     595     def __missing__(self, key):
#
# ~\anaconda3\lib\collections\__init__.py in update(self, iterable, **kwds)
#     677                     super().update(iterable)
#     678             else:
# --> 679                 _count_elements(self, iterable)
#     680         if kwds:
#     681             self.update(kwds)
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
a = a.flatten('C')

# %%
a
# Out:
# array([0, 0, 0, 5, 2, 7, 4, 6, 2, 1, 1, 7, 7, 4, 3, 4, 4, 8, 6, 6, 1, 0,
#        6, 7, 1])

# %%
st.mode(a)
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20bf7c82c70>,
#   <matplotlib.lines.Line2D at 0x20bf7c82f40>],
#  'caps': [<matplotlib.lines.Line2D at 0x20bf7c76250>,
#   <matplotlib.lines.Line2D at 0x20bf7c76520>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20bf7c829a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20bf7c767f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20bf7c76ac0>],
#  'means': []}

# %%
a = np.insert(a,0,20)

# %%
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20bf77db160>,
#   <matplotlib.lines.Line2D at 0x20bf77db430>],
#  'caps': [<matplotlib.lines.Line2D at 0x20bf77db700>,
#   <matplotlib.lines.Line2D at 0x20bf77db9d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20bf77dae50>],
#  'medians': [<matplotlib.lines.Line2D at 0x20bf77dbca0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20bf77dbfa0>],
#  'means': []}

# %%
a
# Out:
# array([ 20, 120, 100,   0,   0,   0,   5,   2,   7,   4,   6,   2,   1,
#          1,   7,   7,   4,   3,   4,   4,   8,   6,   6,   1,   0,   6,
#          7,   1])

# %%
bt=np.transpose(c)
bt
# Out:
# array([[ 52, 110,  17, 113,  40],
#        [ 52, 110,  17, 113,  40],
#        [ 52, 110,  17, 113,  40],
#        [ 52, 110,  17, 113,  40],
#        [ 52, 110,  17, 113,  40]])

# %%
c
# Out:
# array([[ 52,  52,  52,  52,  52],
#        [110, 110, 110, 110, 110],
#        [ 17,  17,  17,  17,  17],
#        [113, 113, 113, 113, 113],
#        [ 40,  40,  40,  40,  40]])

# %%
bi=np.inv

# %%
# c1 homework

# %%
import pandas as pd

# %%
# using dictionary
data = {
    'names':['ajay','binod','chada','dholu'],
    'age':[23,24,19,21],
    'address':['abc','def','ghi','sdf']
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    names  age address
# 0   ajay   23     abc
# 1  binod   24     def
# 2  chada   19     ghi
# 3  dholu   21     sdf

# %%
data2=[['ajay',23,'sff'],['binod',24,'sdf'],['chada',21,'def'],['dholu',19,'uee']]
df2=pd.DataFrame(data2,columns=['name','age','address'])
df2
# Out:
#     name  age address
# 0   ajay   23     sff
# 1  binod   24     sdf
# 2  chada   21     def
# 3  dholu   19     uee

# %%
df3= pd.DataFrame(columns=['id','name','age'])

# %%
df.loc(0)=[1,'ajay',22]
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_12448\309927788.py", line 1
#     df.loc(0)=[1,'ajay',22]
#     ^
# SyntaxError: cannot assign to function call
